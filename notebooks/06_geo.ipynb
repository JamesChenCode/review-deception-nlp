# %% [markdown]
# # 06 — Geospatial (optional)
#
# **Goal:** if reviewer/product location is obtainable, map suspicious-review rates (choropleth / heatmap). Gated by `config['geo']['enabled']`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src import utils, viz
config = utils.load_config()
utils.set_seeds(config["project"]["random_seed"])
viz.set_house_style()
print("source:", config["data_source"]["source"], "| seed:", config["project"]["random_seed"])

# %%
from src import geo
if not config['geo']['enabled']:
    print('Geo disabled (no location data). Skipping — see config.yaml [geo].')
# else: geo.choropleth(...)  # implemented if location data is available
